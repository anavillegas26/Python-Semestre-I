# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Iniciando Nuestro Data Set

# %%
datos = pd.read_csv("Data/games.csv",index_col="Id")
datos.head()
# Out:
#                                       Title  Release Date  \
# Id
# 0                                Elden Ring  Feb 25, 2022
# 1                                     Hades  Dec 10, 2019
# 2   The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                 Undertale  Sep 15, 2015
# 4                             Hollow Knight  Feb 24, 2017
#
#                                                  Team  Rating Times Listed  \
# Id
# 0      ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                                ['Supergiant Games']     4.3         2.9K
# 2   ['Nintendo', 'Nintendo EPD Production Group No...     4.4         4.3K
# 3                                  ['tobyfox', '8-4']     4.2         3.5K
# 4                                     ['Team Cherry']     4.4           3K
#
#    Number of Reviews                                             Genres  \
# Id
# 0               3.9K                               ['Adventure', 'RPG']
# ...

# %% [markdown]
# **Consultando tipo de Datos**

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Dimenciòn del Dataset**

# %%
datos.shape
# Out:
# (1512, 13)

# %%
print(f"Cantidad  de filas y columnas del dataset:{datos.shape}")
# Out:
# Cantidad  de filas y columnas del dataset:(1512, 13)

# %% [markdown]
# **Mostrando información del dataset**

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1512 entries, 0 to 1511
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1512 non-null   object
#  1   Release Date       1512 non-null   object
#  2   Team               1511 non-null   object
#  3   Rating             1499 non-null   float64
#  4   Times Listed       1512 non-null   object
#  5   Number of Reviews  1512 non-null   object
#  6   Genres             1512 non-null   object
#  7   Summary            1511 non-null   object
#  8   Reviews            1512 non-null   object
#  9   Plays              1512 non-null   object
#  10  Playing            1512 non-null   object
#  11  Backlogs           1512 non-null   object
#  12  Wishlist           1512 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 165.4+ KB

# %% [markdown]
# **Mostrando filas de datos nulos**

# %%
datos.isnull()
# Out:
#       Title  Release Date   Team  Rating  Times Listed  Number of Reviews  \
# Id
# 0     False         False  False   False         False              False
# 1     False         False  False   False         False              False
# 2     False         False  False   False         False              False
# 3     False         False  False   False         False              False
# 4     False         False  False   False         False              False
# ...     ...           ...    ...     ...           ...                ...
# 1507  False         False  False   False         False              False
# 1508  False         False  False   False         False              False
# 1509  False         False  False   False         False              False
# 1510  False         False  False   False         False              False
# 1511  False         False  False   False         False              False
#
#       Genres  Summary  Reviews  Plays  Playing  Backlogs  Wishlist
# Id
# ...

# %% [markdown]
# **Identificando las columnas con datos nulos**

# %%
columnas_nulas = datos.isnull().any()
columnas_nulas
# Out:
# Title                False
# Release Date         False
# Team                  True
# Rating                True
# Times Listed         False
# Number of Reviews    False
# Genres               False
# Summary               True
# Reviews              False
# Plays                False
# Playing              False
# Backlogs             False
# Wishlist             False
# dtype: bool

# %% [markdown]
# **Identificando las filas en especifico con datos nulos**

# %%
filas_nulas= datos[datos.isnull().any(axis=1)]  #recordar que datos es nuetro dataset
filas_nulas

# NaN significa valos nulo
# Out:
#                                                   Title     Release Date  \
# Id
# 587                                   Final Fantasy XVI     Jun 22, 2023
# 649                                   Death Stranding 2  releases on TBD
# 713                           Final Fantasy VII Rebirth     Dec 31, 2023
# 719                                           Lies of P     Aug 01, 2023
# 726                                               Judas     Mar 31, 2025
# 746   Like a Dragon Gaiden: The Man Who Erased His Name     Dec 31, 2023
# 972           The Legend of Zelda: Tears of the Kingdom     May 12, 2023
# 1130                           Star Wars Jedi: Survivor     Apr 28, 2023
# 1160            We Love Katamari Reroll + Royal Reverie     Jun 02, 2023
# 1202                                         Earthblade     Dec 31, 2024
# 1245                               NEET Girl Date Night     Oct 21, 2022
# 1305                                          Diablo IV     Jun 06, 2023
# ...

# %% [markdown]
# **Eliminar los datis nnulos del dataset**

# %%
datos_sin_nulos = datos.dropna() # se eliminaron 14 filas
datos_sin_nulos
# Out:
#                                         Title  Release Date  \
# Id
# 0                                  Elden Ring  Feb 25, 2022
# 1                                       Hades  Dec 10, 2019
# 2     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                   Undertale  Sep 15, 2015
# 4                               Hollow Knight  Feb 24, 2017
# ...                                       ...           ...
# 1507             Back to the Future: The Game  Dec 22, 2010
# 1508                        Team Sonic Racing  May 21, 2019
# 1509                           Dragon's Dogma  May 22, 2012
# 1510                          Baldur's Gate 3  Oct 06, 2020
# 1511                 The LEGO Movie Videogame  Feb 04, 2014
#
#                                                    Team  Rating Times Listed  \
# Id
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                                  ['Supergiant Games']     4.3         2.9K
# ...

# %% [markdown]
# **crear una función para verificar si un video juego esta presente en la lista**
#
# en el ejemplo vamos a verificar si se encuentra el genero RPG en la lista

# %%
def filtro_rpg(genres): # funcion que filtra los rpg
    return 'RPG' in genres

# %%
# aplicar un filtro para consultar y llamar la función filtro_rpg
datosPRG = datos[datos['Genres'].apply(filtro_rpg)]

# %%
# mostrar el dataset filtardo; incluyendo solo las 2 columnas titulo y rating
nombreRPG = datosPRG[['Title', 'Rating' ]]
nombreRPG.head(20) # muestra los primeros 20 juegos
# Out:
#                                       Title  Rating
# Id
# 0                                Elden Ring     4.5
# 1                                     Hades     4.3
# 2   The Legend of Zelda: Breath of the Wild     4.4
# 3                                 Undertale     4.2
# 6                                     Omori     4.2
# 9                            NieR: Automata     4.3
# 10                          Persona 5 Royal     4.4
# 12                               God of War     4.2
# 14                               Bloodborne     4.5
# 16                                 Yakuza 0     4.4
# 17                    Red Dead Redemption 2     4.4
# 20                  Pokémon Legends: Arceus     3.7
# 24                           Cyberpunk 2077     3.3
# 26                   Xenoblade Chronicles 3     4.4
# 28             Disco Elysium: The Final Cut     4.6
# 30                           Dark Souls III     4.2
# 31      NieR Replicant ver.1.22474487139...     4.2
# ...

# %%
nombreRPG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 523 entries, 0 to 1510
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   523 non-null    object
#  1   Rating  516 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 12.3+ KB

# %% [markdown]
# **Graficar los primeros 10 video juego y su rating de popularidad**

# %%
graficosRPG = nombreRPG.head(10) #grafico solo tiene los 10 primeros video juego
graficosRPG.drop(['Title'],axis=1)['Rating'].plot(kind='bar')
# Out:
# <Axes: xlabel='Id'>

# %% [markdown]
# **Mejorando el gráfico**

# %%
graficosRPG = nombreRPG.head(10) #grafico solo tiene los 10 primeros video juego
graficosRPG.set_index('Title', inplace=True) # establece la colunma titulo como indice
graficosRPG['Rating'].plot(kind='bar')
# Out:
# <Axes: xlabel='Title'>

# %% [markdown]
# **Agregando etiquetas al gráfico**

# %%
graficosRPG = nombreRPG.head(10) #grafico solo tiene los 10 primeros video juego
graficosRPG.set_index('Title', inplace=True) # establece la colunma titulo como indice
graph = graficosRPG['Rating'].plot(kind='bar')
# agregar las etiquetas númericas de rating en las barras
for i, rating in enumerate(graficosRPG['Rating']):
    graph.annotate(str(rating), xy=(i,rating), ha='center')
